# %% [markdown]
# https://chatgpt.com/share/67296b81-db9c-8002-b254-1ea907809997

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rmuRoAf9-bo', width=800, height=500)

# %% [markdown]
# # 1. Describe (a) the variables you plan to explore, and (b) the analysis you plan to perform
# # 2. Describe (a) the possible results your analysis may produce, and (b) how this could be relevant for the objectives of the course project
# # 3. Include your results if you have already completed an analysis

# %% [markdown]
# # 1. FIRST RESEARCH QUESTION

# %% [markdown]
# ### a.
# Since romantic relationships often play a significant role in social connection and personal well-being, so analyzing their impact could reveal interesting patterns. Im planning to explore more about the romantic relationships status and the frequency of social interactions, which I will analyze different social interaction levels such as frequency, type, and quality across relationship statuses—such as single, dating, or married.
#
# The research question is: How do different relationship statuses influence loneliness and happiness, and what role do social interactions play in these outcomes
#
# The variables are:
# ### --- indicates the relationship status
# DEMO_relationship_status
# ### --- indicates the frequencies from the relationships interactions
# LONELY_ucla_loneliness_scale_companionship
# CONNECTION_activities_sex_p3m
# LONELY_ucla_loneliness_scale_left_out
# ### --- indicates the loneliness from the relationships
# LONELY_dejong_emotional_social_loneliness_scale_emptiness
# LONELY_dejong_emotional_social_loneliness_scale_rely
# LONELY_dejong_emotional_social_loneliness_scale_trust
# LONELY_dejong_emotional_social_loneliness_scale_close
# LONELY_dejong_emotional_social_loneliness_scale_miss
# LONELY_dejong_emotional_social_loneliness_scale_rejected
# ### --- indicates the happiness from the relationships
# LONELY_miss_mattering
# WELLNESS_self_rated_physical_health
# WELLNESS_self_rated_mental_health
# WELLNESS_subjective_happiness_scale_happy
# WELLNESS_subjective_happiness_scale_peers
# WELLNESS_subjective_happiness_scale_always_happy
# WELLNESS_subjective_happiness_scale_never_happy
# ### --- indicates the from the social interactions
# PSYCH_social_interactions_anxiety_scale_eye_contact
# PSYCH_social_interactions_anxiety_scale_mixing
# PSYCH_social_interactions_anxiety_scale_aquiantance

# %% [markdown]
# ### b.

# %% [markdown]
# I plan to make hypothesis testing on the data. Since the variables are among single, dating and married, so my null hypothesis is that There is no significant difference in loneliness or happiness scores among different relationship statuses., for instance singles, dating individuals, and married individuals all have similar levels of happiness and loniless. The alternative hypothesis is that There is a significant difference in loneliness or happiness scores among different relationship statuses., where this implies that being single, dating, or married affects happiness or loniless.

# %% [markdown]
# ## 2.

# %% [markdown]
# ### a.
# There are 2 possible results that the hypothesis:
# 1. No Significant Difference, while the p-value is > 0.05, this would suggest there’s no significant difference in social interaction frequency between single, dating, and married individuals. This could indicate that relationship status does not impact how often people interact socially.
# 2. Significant Difference Found, while the p-value < 0.05, it would indicate that relationship status affects the happiness or loniless. A post-hoc test could reveal that single individuals, for example, have more frequent interactions with their partners than married individuals. This would suggest that relationship commitments may influence time spent when they are happy or lonely.

# %% [markdown]
# ### b.
# It is relevant for the objectives of the course project that we are told by the restrictions that to uncover insights into how different forms of social connections—such as relationships with family, friends, coworkers, and neighbors—contribute to well-being. By analyzing romantic relationships specifically, we can be understanding of social dynamics, particularly regarding how the connections might impact or work among other forms of social interaction. From this analysis could show if romantic relationships reduce the need for other social connections or if they are impacting with active social lives. This is great for understanding the “social connection” which is the purpose of the project.

# %% [markdown]
# ## 3.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Simulated data
np.random.seed(42)
n = 300
data = {
    'DEMO_relationship_status': np.random.choice(['Single', 'Dating', 'Married'], n),
    'LONELY_ucla_loneliness_scale_companionship': np.concatenate([
        np.random.normal(3.5, 1.0, n // 3),  # Single
        np.random.normal(2.5, 0.8, n // 3),  # Dating
        np.random.normal(4.0, 1.2, n // 3)   # Married
    ]),
    'WELLNESS_subjective_happiness_scale_happy': np.concatenate([
        np.random.normal(4.0, 1.0, n // 3),  # Single
        np.random.normal(5.0, 0.9, n // 3),  # Dating
        np.random.normal(3.5, 1.1, n // 3)   # Married
    ]),
    'PSYCH_social_interactions_anxiety_scale_eye_contact': np.random.normal(3.0, 1.0, n),
}

# Create DataFrame
df = pd.DataFrame(data)

# Descriptive Statistics
print(df.describe())

# Boxplots for Loneliness and Happiness by Relationship Status
plt.figure(figsize=(12, 5))

# Loneliness
plt.subplot(1, 2, 1)
sns.boxplot(x='DEMO_relationship_status', y='LONELY_ucla_loneliness_scale_companionship', data=df)
plt.title('Loneliness by Relationship Status')
plt.xlabel('Relationship Status')
plt.ylabel('Loneliness Score')

# Happiness
plt.subplot(1, 2, 2)
sns.boxplot(x='DEMO_relationship_status', y='WELLNESS_subjective_happiness_scale_happy', data=df)
plt.title('Happiness by Relationship Status')
plt.xlabel('Relationship Status')
plt.ylabel('Happiness Score')

plt.tight_layout()
plt.show()

# ANOVA test
model = ols('LONELY_ucla_loneliness_scale_companionship ~ DEMO_relationship_status', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#        LONELY_ucla_loneliness_scale_companionship  \
# count                                  300.000000
# mean                                     3.335309
# std                                      1.221896
# min                                     -0.173803
# 25%                                      2.559669
# 50%                                      3.183468
# 75%                                      4.096707
# max                                      7.047109
#
#        WELLNESS_subjective_happiness_scale_happy  \
# count                                 300.000000
# mean                                    4.248933
# std                                     1.268788
# min                                    -0.425026
# 25%                                     3.395062
# 50%                                     4.274370
# 75%                                     5.099256
# max                                     7.856998
#
#        PSYCH_social_interactions_anxiety_scale_eye_contact
# ...

# %% [markdown]
# I asked ChatGPT to simulate the data for us and we know
# Singles: Mean loneliness = 3.5, Happiness = 4.0
# Dating: Mean loneliness = 2.5, Happiness = 5.0
# Married: Mean loneliness = 4.0, Happiness = 3.5
# Then we can calculate the p-value with graphs on it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import norm

# Simulated data
np.random.seed(42)
n = 300
data = {
    'DEMO_relationship_status': np.random.choice(['Single', 'Dating', 'Married'], n),
    'LONELY_ucla_loneliness_scale_companionship': np.concatenate([
        np.random.normal(3.5, 1.0, n // 3),  # Single
        np.random.normal(2.5, 0.8, n // 3),  # Dating
        np.random.normal(4.0, 1.2, n // 3)   # Married
    ]),
}

# Create DataFrame
df = pd.DataFrame(data)

# ANOVA test
model = ols('LONELY_ucla_loneliness_scale_companionship ~ DEMO_relationship_status', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Extract p-value
p_value = anova_table.loc['DEMO_relationship_status', 'PR(>F)']

# Plotting the bell curves
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Define the range for the x-axis
x = np.linspace(0, 8, 1000)

# Colors for each relationship status
colors = {'Single': 'skyblue', 'Dating': 'lightgreen', 'Married': 'salmon'}

# Create bell curves for each group
for status in df['DEMO_relationship_status'].unique():
    data_group = df[df['DEMO_relationship_status'] == status]
    mu = data_group['LONELY_ucla_loneliness_scale_companionship'].mean()
    sigma = data_group['LONELY_ucla_loneliness_scale_companionship'].std()
    n = len(data_group)
    
    # Calculate 95% confidence interval
    z = norm.ppf(0.975)  # 95% confidence
    ci_lower = mu - z * (sigma / np.sqrt(n))
    ci_upper = mu + z * (sigma / np.sqrt(n))

    # Create the bell curve
    plt.plot(x, (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(- 0.5 * ((x - mu) / sigma) ** 2), 
             label=status, color=colors[status])
    
    # Plot confidence intervals
    plt.fill_between(x, 
                     (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(- 0.5 * ((x - ci_lower) / sigma) ** 2), 
                     (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(- 0.5 * ((x - ci_upper) / sigma) ** 2), 
                     color=colors[status], alpha=0.2)
    
    # Annotate confidence interval, adjusting the y position to avoid overlap
    y_position = 0.02 if status == 'Single' else 0.03 if status == 'Dating' else 0.04
    plt.text(mu, y_position, f'CI: [{ci_lower:.2f}, {ci_upper:.2f}]', ha='center', fontsize=10, color='black')

# Adding annotations
plt.axhline(y=0, color='black', linewidth=0.5)
plt.axvline(x=3, color='gray', linestyle='--', label='Sample Mean')
plt.title('Bell Curves of Loneliness Scores by Relationship Status with Confidence Intervals')
plt.xlabel('Loneliness Score')
plt.ylabel('Probability Density')
plt.legend()

# Annotate the p-value on the plot
plt.text(4, 0.1, f'P-Value: {p_value:.4f}', ha='center', fontsize=12, color='black')

# Show the plot
plt.show()

# %% [markdown]
# Since the simulated p-value is 0.8316, we fail to reject the null hypothesis. This indicates that there is no statistically significant difference in loneliness scores across the different relationship statuses (Single, Dating, Married) based on the simulated data.
# But yet, its only the simulated data from chatgpt, we will have amuch precise data once we get into the survey data from the CSCS data.

# %% [markdown]
# ## 1. SECOND RESEARCH QUESTION

# %% [markdown]
# ### a.
# Since social media often plays a significant role in social connection and personal well-being, so analyzing their impact could reveal interesting patterns. It investigates how early adverse experiences influence the prevalence of mental health issues in adulthood, such as anxiety, depression, or PTSD.
#
#
# For the second research question im planning to do: What are the long-term effects of childhood trauma on adult mental health outcomes?
#
# The variables are:
# ### ---indicates the ages
# DEMO_age
#
# ### ---indicates the mental health
# KNOWLEDGE_important_mental
# WELLNESS_self_rated_mental_health
#
# ### ---indicates if theres any mental illness
# DEMO_identity_mental_health
# DEMO_disability_mental_health
#
# ### ---indicates the childhood trauma
# LIFECOURSE_childhood_adult_relationships_unknown_scale_proud
# LIFECOURSE_childhood_adult_relationships_unknown_scale_interest
# LIFECOURSE_childhood_adult_relationships_unknown_scale_listened
# LIFECOURSE_childhood_adult_relationships_unknown_scale_there
# LIFECOURSE_childhood_adult_relationships_unknown_scale_spoke
# LIFECOURSE_childhood_adult_relationships_unknown_scale_share
# LIFECOURSE_childhood_adult_relationships_unknown_scale_help

# %% [markdown]
# ### b.
# We can use linear regression or hypothesis checking, since we've done hypothesis checking for the first research question, imma do it in linear regression where we can define every variables that I've mentioned before with values, which the dependent variables are the scores of self rated mantal health disability mental health, in the other hand the independent variables are the trauma scale.

# %% [markdown]
# ## 2.

# %% [markdown]
# ### a.
# There are several possible outcomes that may occured which one is that childhood trauma is positively associated with poor mental health outcomes, which means the higher levels of childhood trauma relates with higher scores of depression, anxiety, or PTSD in adulthood. This suggests that reducing trauma in childhood may be important for improving mental health later in life. The other possible outcome is that its a negative relationship, which is less common but theoretically possible. Or maybe there isn't any significant relationship where (p-value ≥ 0.05), There may be other factors influencing adult mental health that are not captured by childhood trauma alone. This could lead to exploring additional variables, such as social support.

# %% [markdown]
# ### b.

# %% [markdown]
# The analysis explores childhood trauma, a precise predictions of mental health, providing insights into how early life experiences shape psychological well-being in adulthood. This meets the project goal of identifying key influences on mental health, especially those that can inform preventative strategies. By understanding these connections, you contribute to a broader knowledge base essential for effective mental health interventions.

# %% [markdown]
# ## 3.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# Set random seed for reproducibility
np.random.seed(42)

# Simulate ACE (childhood trauma) scores
n = 100
ace_scores = np.random.randint(0, 11, size=n)

# Simulate adult mental health outcomes with a positive association to ACE scores
# We add random noise to reflect natural variation
mental_health_scores = 2.5 * ace_scores + np.random.normal(0, 5, size=n)

# Create DataFrame
data = pd.DataFrame({
    'ACE_Score': ace_scores,
    'Mental_Health_Score': mental_health_scores
})

# Add constant for the intercept
X = sm.add_constant(data['ACE_Score'])
y = data['Mental_Health_Score']

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the summary
model_summary = model.summary()
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Mental_Health_Score   R-squared:                       0.727
# Model:                             OLS   Adj. R-squared:                  0.724
# Method:                  Least Squares   F-statistic:                     260.8
# Date:                 Tue, 05 Nov 2024   Prob (F-statistic):           2.26e-29
# Time:                         04:40:19   Log-Likelihood:                -302.21
# No. Observations:                  100   AIC:                             608.4
# Df Residuals:                       98   BIC:                             613.6
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# I asked ChatGPT to simulate the data for me and provides me the graph of inear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Set up random seed for reproducibility
np.random.seed(42)

# Simulate data
n = 100
ace_scores = np.random.randint(0, 11, size=n)
mental_health_scores = 2.5 * ace_scores + np.random.normal(0, 5, size=n)
data = pd.DataFrame({'ACE_Score': ace_scores, 'Mental_Health_Score': mental_health_scores})

# Add constant for the intercept
X = sm.add_constant(data['ACE_Score'])
y = data['Mental_Health_Score']
model = sm.OLS(y, X).fit()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(data['ACE_Score'], data['Mental_Health_Score'], color='blue', alpha=0.6, label='Data Points')
plt.plot(data['ACE_Score'], model.predict(X), color='red', label='Regression Line')
plt.xlabel("Childhood Trauma Score (ACE Score)")
plt.ylabel("Adult Mental Health Score")
plt.title("Relationship Between Childhood Trauma and Adult Mental Health Outcomes")
plt.legend()
plt.show()

# %% [markdown]
# Turns out this result emphasizes the need for early intervention and mental health support for individuals with high childhood trauma. Since 39% of the variance remains unexplained, additional factors (e.g., social support, resilience) should be investigated to understand what might buffer or amplify the effects of trauma.

# %% [markdown]
# ## 1. THIRD RESEARCH QUESTION

# %% [markdown]
# ### a.

# %% [markdown]
# The third research question im gonna explore about the job stress and mental health
#
# Research question: How does social support influence the relationship between job stress and mental health outcomes in adults?
#
# Variables that im gonna use:
#
# ### ---indicates the jobs
# DEMO_occupation
#
# ### ---indicates the stress of work
# WORK_feel_quitting
# WORK_feel_stress
# CONNECTION_activities_talked_job_p3m
#
# ### ---indicates the depression
# WELLNESS_malach_pines_burnout_measure_depressed
# WELLNESS_phq_feeling_down
# WELLNESS_depression_diagnosis
# WELLNESS_anxiety_diagnosis

# %% [markdown]
# ### b.
# Im gonna conduct a linear regression again that includes an interaction term between job stress and social support. This will help determine if social support changes the strength or direction of the relationship between job stress and mental health. If a significant effect is found, it would suggest that social support either reduces or increases the impact of job stress on mental health.

# %% [markdown]
# ## 2.

# %% [markdown]
# ### a.

# %% [markdown]
# There are 3 possible outcomes that may occur among this situation. One is that it reduces the impact of the job stress on mental health which suggesting that supportive relationships can help mitigate stress. The other possible outcome is that there's non effect where social support does not change the relationship, implying that job stress independently impacts mental health regardless of the level of support. The last possible outcome is that its having a increasing impact of mental health, leading to higher reported mental health impacts.

# %% [markdown]
# ### b.

# %% [markdown]
# This research question examines the interaction between job stresses and personal resources social support that influence mental health. We can explore the importance of not only individual factors but also environmental and social determinants. By analyzing how these elements combine, you deepen understanding of how mental health is impacted by everyday experiences and support systems.

# %% [markdown]
# ## 3.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seed for reproducibility
np.random.seed(42)

# Number of samples
n = 200

# Simulate job stress scores (0 = low stress, 1 = high stress)
job_stress = np.random.choice([0, 1], size=n)

# Simulate social support scores (range 1-5, higher indicates more support)
social_support = np.random.randint(1, 6, size=n)

# Simulate mental health outcomes with main effects and interaction effect
# Convert to float to allow addition of noise
mental_health = 30.0 + (15 * job_stress) - (3 * social_support) + (2 * job_stress * social_support)
mental_health += np.random.normal(0, 5, size=n)  # Add some random noise

# Create DataFrame
data = pd.DataFrame({
    'Job_Stress': job_stress,
    'Social_Support': social_support,
    'Mental_Health_Score': mental_health
})

# Display first few rows of the simulated data
print(data.head())

# Fit the regression model with an interaction term
X = data[['Job_Stress', 'Social_Support']]
X['Interaction'] = X['Job_Stress'] * X['Social_Support']  # Interaction term
X = sm.add_constant(X)  # Add constant for intercept
y = data['Mental_Health_Score']

# Fit the model
model = sm.OLS(y, X).fit()
print(model.summary())

# Plot interaction effect
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x="Social_Support", y="Mental_Health_Score", hue="Job_Stress", palette="coolwarm")
plt.title("Interaction Effect of Social Support and Job Stress on Mental Health")
plt.xlabel("Social Support")
plt.ylabel("Mental Health Score")
plt.legend(title="Job Stress", loc='upper right')
plt.show()
# Out:
#    Job_Stress  Social_Support  Mental_Health_Score
# 0           0               1            29.248870
# 1           1               4            49.894622
# 2           0               5            11.665283
# 3           0               4             9.540909
# 4           0               5            18.283987
#                              OLS Regression Results
# ...
# Dep. Variable:     Mental_Health_Score   R-squared:                       0.844
# Model:                             OLS   Adj. R-squared:                  0.842
# Method:                  Least Squares   F-statistic:                     353.8
# Date:                 Tue, 05 Nov 2024   Prob (F-statistic):           8.10e-79
# Time:                         04:58:33   Log-Likelihood:                -601.52
# No. Observations:                  200   AIC:                             1211.
# Df Residuals:                      196   BIC:                             1224.
# Df Model:                            3
# ...

# %%
# Set up the plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x="Social_Support", y="Mental_Health_Score", hue="Job_Stress", palette="coolwarm", alpha=0.7)

# Adding a regression line for each level of Job Stress
for stress_level in data['Job_Stress'].unique():
    subset = data[data['Job_Stress'] == stress_level]
    X_subset = sm.add_constant(subset['Social_Support'])  # Add constant for intercept
    model_subset = sm.OLS(subset['Mental_Health_Score'], X_subset).fit()
    plt.plot(subset['Social_Support'], model_subset.predict(X_subset), 
             label=f"Job Stress = {stress_level}", color="red" if stress_level == 1 else "blue")

# Labeling the plot
plt.title("Interaction Effect of Social Support and Job Stress on Mental Health Outcomes")
plt.xlabel("Social Support Level")
plt.ylabel("Mental Health Score")
plt.legend(title="Job Stress", loc='upper right')
plt.show()
